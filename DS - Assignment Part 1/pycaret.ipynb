# %%
# load libraries
import pandas as pd
import numpy as np
from pycaret.regression import *

df = pd.read_excel('DS - Assignment Part 1 data set.xlsx')
#remane columns
df.rename(columns={'Distance from nearest Metro station (km)':'nearest Metro(km)','House price of unit area': 'Price'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Transaction date              414 non-null    float64
#  1   House Age                     414 non-null    float64
#  2   nearest Metro(km)             414 non-null    float64
#  3   Number of convenience stores  414 non-null    int64
#  4   latitude                      414 non-null    float64
#  5   longitude                     414 non-null    float64
#  6   Number of bedrooms            414 non-null    int64
#  7   House size (sqft)             414 non-null    int64
#  8   Price                         414 non-null    float64
# dtypes: float64(6), int64(3)
# memory usage: 29.2 KB

# %%
df.drop('Transaction date', axis=1, inplace=True)

# %%
# pycaret for regression
from pycaret.regression import *
reg = setup(data = df, target = 'Price', normalize=False, 
transformation= False, ignore_low_variance=True, remove_outliers=False)
# Out:
#
# Setup Succesfully Completed.
# <style type="text/css">
# #T_49bd9_row22_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_49bd9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49bd9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_49bd9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49bd9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49bd9_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_49bd9_row0_col1" class="data row0 col1" >1975</td>
#     </tr>
#     <tr>
#       <th id="T_49bd9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_49bd9_row1_col0" class="data row1 col0" >Transform Target </td>
#       <td id="T_49bd9_row1_col1" class="data row1 col1" >False</td>
#     </tr>
#     <tr>
# ...

# %%
gbr = create_model('rf')
# Out:
# <style type="text/css">
# #T_871eb_row10_col0, #T_871eb_row10_col1, #T_871eb_row10_col2, #T_871eb_row10_col3, #T_871eb_row10_col4, #T_871eb_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_871eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_871eb_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_871eb_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_871eb_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_871eb_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_871eb_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_871eb_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_871eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_871eb_row0_col0" class="data row0 col0" >6.4956</td>
# ...

# %%
tune_model(gbr)
# Out:
# <style type="text/css">
# #T_c7dc5_row10_col0, #T_c7dc5_row10_col1, #T_c7dc5_row10_col2, #T_c7dc5_row10_col3, #T_c7dc5_row10_col4, #T_c7dc5_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c7dc5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7dc5_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c7dc5_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c7dc5_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c7dc5_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c7dc5_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c7dc5_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7dc5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7dc5_row0_col0" class="data row0 col0" >6.3299</td>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_810b3 th {
#   text-align: left;
# }
# ...

# %%
xgb = create_model('xgboost')
# Out:
# <style type="text/css">
# #T_68a57_row10_col0, #T_68a57_row10_col1, #T_68a57_row10_col2, #T_68a57_row10_col3, #T_68a57_row10_col4, #T_68a57_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_68a57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68a57_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_68a57_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_68a57_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_68a57_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_68a57_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_68a57_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68a57_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68a57_row0_col0" class="data row0 col0" >6.9108</td>
# ...

# %%
tuned_xgb = tune_model(xgb)
# Out:
# <style type="text/css">
# #T_b7c33_row10_col0, #T_b7c33_row10_col1, #T_b7c33_row10_col2, #T_b7c33_row10_col3, #T_b7c33_row10_col4, #T_b7c33_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b7c33">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7c33_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b7c33_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b7c33_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b7c33_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b7c33_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b7c33_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7c33_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b7c33_row0_col0" class="data row0 col0" >7.0246</td>
# ...
